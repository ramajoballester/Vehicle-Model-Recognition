# %%
import argparse
import git
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from utils import *
from tensorflow.keras.layers import Input, Dense, Flatten, Concatenate, Subtract
import datetime
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'

n_classes = 196
n_elements = 300



gpus = tf.config.experimental.list_physical_devices('GPU')
try:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
except RuntimeError as e:
    print(e)


ROOT_DIR = get_git_root(os.getcwd())


car_names = os.listdir(os.path.join(ROOT_DIR, 'dataset'))
labels = random.sample(car_names, k = n_classes)

(trainX, trainY), (testX, testY), (trainX_bbox, testX_bbox) = load_dataset(ROOT_DIR, labels, n_elements, img_resolution=(224,224),
                                                                                 crop=True, greyscale=False, random_sample = False)
trainX = np.asarray(trainX)
trainY = np.asarray(trainY)
testX = np.asarray(testX)
testY = np.asarray(testY)

# %%
trainX = np.expand_dims(trainX, axis=-1)
testX = np.expand_dims(testX, axis=-1)
norm_trainY = normalize_labels(trainY)
norm_testY = normalize_labels(testY)

input_shape = trainX.shape[1:4]

(trainX, trainY) = make_pairs(trainX, norm_trainY)
(testX, testY) = make_pairs(testX, norm_testY)
trainX = [trainX[:, 0], trainX[:, 1]]
testX = [testX[:, 0], testX[:, 1]]

# %%
# model = tf.keras.applications.VGG16(include_top=False, weights='imagenet',
#                             input_shape=input_shape, pooling='max')

model = tf.keras.models.load_model('../models/EfB3-full-299/')


for each_layer in model.layers:
    each_layer.trainable = False


inputA = Input(shape=input_shape)
inputB = Input(shape=input_shape)
featsA = model(inputA)
featsB = model(inputB)
# distance = Lambda(utils.euclidean_distance)([featsA, featsB])
# feats = Concatenate()([featsA, featsB])
feats = Subtract()([featsA, featsB])
# feats = Dense(4096, activation='relu', name='Dense_1')(feats)
# output = Dense(4096, activation='relu', name='Dense_2')(feats)
# output = Dense(1, activation="sigmoid")(output)
model = tf.keras.models.Model([inputA, inputB], feats)
# Out:
# WARNING:tensorflow:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_646866) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_646683) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_641875) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_645553) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_595976) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_636844) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_593851) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_601664) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_597309) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_599486) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_630373) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_637974) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_637266) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_595042) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_602415) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_599345) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_596423) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_596328) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_599439) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_602955) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_636884) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_645035) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_597708) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_639662) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_642440) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_646261) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_640562) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_646826) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_636183) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_645696) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_594690) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_643905) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_596722) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_643340) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_642775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_595184) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_599885) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_640180) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_593121) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_647813) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_594150) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_600331) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_598647) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_601969) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_635400) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_635257) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_604146) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_600378) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_600825) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_603002) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_638914) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_646118) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_597755) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_598154) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_635801) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_602110) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_648521) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_647956) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_644088) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_644613) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_593027) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_596863) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_603841) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_643523) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_645178) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_598600) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_600778) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_645218) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_644048) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_641310) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_639622) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_601617) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_647996) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_640140) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_603401) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_602861) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_637409) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_598993) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_638349) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_637449) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_601077) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_model_layer_call_and_return_conditional_losses_622688) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_595882) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_598506) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_639479) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_600683) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_648896) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_602556) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_649461) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_597262) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_595577) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_603307) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_594596) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_641270) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_efficientnetb3_layer_call_and_return_conditional_losses_632966) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_642400) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_593404) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_603448) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_602063) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_603700) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_648378) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_601218) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_647391) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_603794) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_638532) with ops with custom gradients. Will likely fail if a gradient is requested.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ba565216b54a> in <module>
#       2 #                             input_shape=input_shape, pooling='max')
#       3
# ----> 4 model = tf.keras.models.load_model('../models/EfB3-full-299/')
#       5
#       6
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     188     if isinstance(filepath, six.string_types):
#     189       loader_impl.parse_saved_model(filepath)
# --> 190       return saved_model_load.load(filepath, compile)
#     191
#     192   raise IOError(
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in load(path, compile)
#     114   # TODO(kathywu): Add saving/loading of optimizer, compiled losses and metrics.
#     115   # TODO(kathywu): Add code to load from objects that contain all endpoints
# --> 116   model = tf_load.load_internal(path, loader_cls=KerasObjectLoader)
#     117
#     118   # pylint: disable=protected-access
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in load_internal(export_dir, tags, loader_cls)
#     600     object_graph_proto = meta_graph_def.object_graph_def
#     601     with ops.init_scope():
# --> 602       loader = loader_cls(object_graph_proto,
#     603                           saved_model_proto,
#     604                           export_dir)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in __init__(self, *args, **kwargs)
#     186     self._models_to_reconstruct = []
#     187
# --> 188     super(KerasObjectLoader, self).__init__(*args, **kwargs)
#     189
#     190     # Now that the node object has been fully loaded, and the checkpoint has
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/saved_model/load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir)
#     121       self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     122
# --> 123     self._load_all()
#     124     self._restore_checkpoint()
#     125
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in _load_all(self)
#     207     # loaded from config may create variables / other objects during
#     208     # initialization. These are recorded in `_nodes_recreated_from_config`.
# --> 209     self._layer_nodes = self._load_layers()
#     210
#     211     # Load all other nodes and functions.
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in _load_layers(self)
#     307         continue
#     308
# --> 309       layers[node_id] = self._load_layer(proto.user_object, node_id)
#     310
#     311     for node_id, proto in metric_list:
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in _load_layer(self, proto, node_id)
#     333     # Detect whether this object can be revived from the config. If not, then
#     334     # revive from the SavedModel instead.
# --> 335     obj, setter = self._revive_from_config(proto.identifier, metadata, node_id)
#     336     if obj is None:
#     337       obj, setter = revive_custom_object(proto.identifier, metadata)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in _revive_from_config(self, identifier, metadata, node_id)
#     351       obj = (
#     352           self._revive_graph_network(metadata, node_id) or
# --> 353           self._revive_layer_from_config(metadata, node_id))
#     354
#     355     if obj is None:
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in _revive_layer_from_config(self, metadata, node_id)
#     405
#     406     try:
# --> 407       obj = layers_module.deserialize(
#     408           generic_utils.serialize_keras_class_and_config(class_name, config))
#     409     except ValueError:
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#     103     config['class_name'] = _DESERIALIZATION_TABLE[layer_class_name]
#     104
# --> 105   return deserialize_keras_object(
#     106       config,
#     107       module_objects=globs,
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     373                 list(custom_objects.items())))
#     374       with CustomObjectScope(custom_objects):
# --> 375         return cls.from_config(cls_config)
#     376     else:
#     377       # Then `cls` may be a function returning a class.
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in from_config(cls, config)
#     653         A layer instance.
#     654     """
# --> 655     return cls(**config)
#     656
#     657   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/layers/preprocessing/image_preprocessing.py in __init__(self, scale, name, **kwargs)
#     314   def __init__(self, scale, name=None, **kwargs):
#     315     self.scale = scale
# --> 316     super(Rescaling, self).__init__(name=name, **kwargs)
#     317
#     318   def call(self, inputs):
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     454     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     455     try:
# --> 456       result = method(self, *args, **kwargs)
#     457     finally:
#     458       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     292     }
#     293     # Validate optional keyword arguments.
# --> 294     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     295
#     296     # Mutable properties
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     790   for kwarg in kwargs:
#     791     if kwarg not in allowed_kwargs:
# --> 792       raise TypeError(error_message, kwarg)
#     793
#     794
#
# TypeError: ('Keyword argument not understood:', 'offset')

# %%
trainX_emb = model.predict(trainX)
testX_emb = model.predict(testX)
trainY = np.squeeze(trainY, 1)
testY = np.squeeze(testY, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-49802407ac3b> in <module>
# ----> 1 trainX_emb = model.predict(trainX)
#       2 testX_emb = model.predict(testX)
#       3 trainY = np.squeeze(trainY, 1)
#       4 testY = np.squeeze(testY, 1)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1266           for step in data_handler.steps():
#    1267             callbacks.on_predict_batch_begin(step)
# -> 1268             tmp_batch_outputs = predict_function(iterator)
#    1269             # Catch OutOfRangeError for Datasets of unknown size.
#    1270             # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.compile()
svm_model = SVC(kernel='rbf', verbose=True)

# %%
svm_model.fit(trainX_emb, trainY)
# Out:
# [LibSVM]
# SVC(verbose=True)

# %%
trainY_preds = svm_model.predict(trainX_emb)
testY_preds = svm_model.predict(testX_emb)
print(accuracy_score(trainY_preds, trainY))
print(accuracy_score(testY_preds, testY))
# Out:
# 0.9116169932488062
# 0.7354543203763307

# %%
import pickle
with open('svm_rbf.pickle', 'wb') as file:
    pickle.dump(svm_model, file)

# %%
# !pwd
# Out:
# /home/alvaro/Vehicle-Model-Recognition/dataset

# %% [markdown]
# ### Previous: 91.16% training - 73.55% val
